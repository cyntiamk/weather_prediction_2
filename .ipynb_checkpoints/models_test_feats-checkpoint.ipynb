# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlite3

# %%
connex = sqlite3.connect("weather_predict.db")  # Opens file if exists, else creates file
cur = connex.cursor()

# %%
query_city1 = 'kyoto_train_feats'
query1 = "SELECT * FROM " + query_city1

query_city2 = 'salvador_train_feats'
query2 = "SELECT * FROM " + query_city2

query_city3 = 'kauai_train_feats'
query3 = "SELECT * FROM " + query_city3

query_city4 = 'nice_train_feats'
query4 = "SELECT * FROM " + query_city4

query_city5 = 'manly_train_feats'
query5 = "SELECT * FROM " + query_city5

# %%
df1 = pd.read_sql(query1, con=connex).set_index('Date')
df2 = pd.read_sql(query2, con=connex).set_index('Date')
df3 = pd.read_sql(query3, con=connex).set_index('Date')
df4 = pd.read_sql(query4, con=connex).set_index('Date')
df5 = pd.read_sql(query5, con=connex).set_index('Date')

# %%
frames = [df1,df2,df3,df4,df5]
df = pd.concat(frames)

# %%
#df.corr()[['Avg_temp']].sort_values('Avg_temp')

# %%
# remove features that have very low Correlation values
# also remove max and min temperatures since we already 
# have the mean temperatures
predictors = [
              'Temp_max_1','Temp_max_2', 'Temp_max_3',
              'Temp_min_1', 'Temp_min_2', 'Temp_min_3',
              'Avg_dwp_1', 'Avg_dwp_2', 'Avg_dwp_3', 
              'Max_dwp_1', 'Max_dwp_2','Max_dwp_3', 
              'Min_dwp_1', 'Min_dwp_2', 'Min_dwp_3']
              
X = df1[predictors]
y = df1['Avg_temp']
# Out:
# (727, 15) (727, 1)

# %%
# manually set the parameters of the figure to and appropriate size
plt.rcParams['figure.figsize'] = [16, 22]

# call subplots specifying the grid structure we desire and that 
# the y axes should be shared
fig, axes = plt.subplots(nrows=5, ncols=3, sharey=True)

# Since it would be nice to loop through the features in to build this plot
# let us rearrange our data into a 2D array of 6 rows and 3 columns
arr = np.array(predictors).reshape(5, 3)

# use enumerate to loop over the arr 2D array of rows and columns
# and create scatter plots of each meantempm vs each feature
for row, col_arr in enumerate(arr):  
    for col, feature in enumerate(col_arr):
        axes[row, col].scatter(df[feature], df['Avg_temp'])
        if col == 0:
            axes[row, col].set(xlabel=feature, ylabel='Avg_temp')
        else:
            axes[row, col].set(xlabel=feature)
plt.show()

# %%
import statsmodels.api as sm

# separate our my predictor variables (X) from my outcome variable y
X = df[predictors]
y = df['Avg_temp']

# Add a constant to the predictor variable set to represent the Bo intercept
X = sm.add_constant(X)  
X.ix[:5, :5]
# Out:
# /anaconda3/envs/PythonData/lib/python3.6/site-packages/ipykernel/__main__.py:9: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#             const  Temp_max_1  Temp_max_2  Temp_max_3  Temp_min_1
# Date
# 2017-01-04    1.0        14.0        12.0        13.0        -2.0
# 2017-01-05    1.0        14.0        14.0        12.0         0.0
# 2017-01-06    1.0        10.0        14.0        14.0         2.0
# 2017-01-07    1.0        10.0        10.0        14.0        -5.0
# 2017-01-08    1.0        10.0        10.0        10.0         0.0

# %%
# (1) select a significance value
alpha = 0.05

# (2) Fit the model
model = sm.OLS(y, X).fit()

# (3) evaluate the coefficients' p-values
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Avg_temp   R-squared:                       0.937
# Model:                            OLS   Adj. R-squared:                  0.937
# Method:                 Least Squares   F-statistic:                     3568.
# Date:                Mon, 28 Jan 2019   Prob (F-statistic):               0.00
# Time:                        11:52:47   Log-Likelihood:                -7279.3
# No. Observations:                3619   AIC:                         1.459e+04
# Df Residuals:                    3603   BIC:                         1.469e+04
# Df Model:                          15
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.8850      0.169     11.141      0.000       1.553       2.217
# Temp_max_1     0.2974      0.013     23.308      0.000       0.272       0.322
# Temp_max_2     0.0493      0.014      3.478      0.001       0.021       0.077
# Temp_max_3     0.0469      0.013      3.592      0.000       0.021       0.073
# Temp_min_1     0.1497      0.017      8.581      0.000       0.115       0.184
# Temp_min_2     0.0433      0.018      2.348      0.019       0.007       0.079
# Temp_min_3     0.1794      0.017     10.467      0.000       0.146       0.213
# Avg_dwp_1      0.3561      0.030     11.857      0.000       0.297       0.415
# Avg_dwp_2     -0.1092      0.032     -3.374      0.001      -0.173      -0.046
# Avg_dwp_3      0.1541      0.030      5.140      0.000       0.095       0.213
# Max_dwp_1     -0.0906      0.012     -7.503      0.000      -0.114      -0.067
# Max_dwp_2      0.0023      0.012      0.192      0.848      -0.022       0.026
# Max_dwp_3     -0.0141      0.012     -1.164      0.244      -0.038       0.010
# Min_dwp_1      0.0077      0.020      0.384      0.701      -0.032       0.047
# Min_dwp_2     -0.0265      0.021     -1.252      0.211      -0.068       0.015
# Min_dwp_3     -0.0957      0.020     -4.788      0.000      -0.135      -0.057
# ==============================================================================
# Omnibus:                      349.520   Durbin-Watson:                   1.707
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1602.955
# Skew:                          -0.363   Prob(JB):                         0.00
# Kurtosis:                       6.179   Cond. No.                         410.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# (3) cont. - Identify the predictor with the greatest p-value and assess if its > our selected alpha.
#             based off the table it is clear that meandewptm_3 has the greatest p-value and that it is
#             greater than our alpha of 0.05

# (4) - Use pandas drop function to remove this column from X
X = X.drop('Max_dwp_2', axis=1)

# (5) Fit the model 
model = sm.OLS(y, X).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Avg_temp   R-squared:                       0.937
# Model:                            OLS   Adj. R-squared:                  0.937
# Method:                 Least Squares   F-statistic:                     3824.
# Date:                Mon, 28 Jan 2019   Prob (F-statistic):               0.00
# Time:                        11:54:04   Log-Likelihood:                -7279.3
# No. Observations:                3619   AIC:                         1.459e+04
# Df Residuals:                    3604   BIC:                         1.468e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.8855      0.169     11.148      0.000       1.554       2.217
# Temp_max_1     0.2972      0.013     23.409      0.000       0.272       0.322
# Temp_max_2     0.0503      0.013      3.816      0.000       0.024       0.076
# Temp_max_3     0.0467      0.013      3.589      0.000       0.021       0.072
# Temp_min_1     0.1498      0.017      8.587      0.000       0.116       0.184
# Temp_min_2     0.0428      0.018      2.345      0.019       0.007       0.079
# Temp_min_3     0.1796      0.017     10.493      0.000       0.146       0.213
# Avg_dwp_1      0.3555      0.030     11.915      0.000       0.297       0.414
# Avg_dwp_2     -0.1061      0.028     -3.776      0.000      -0.161      -0.051
# Avg_dwp_3      0.1537      0.030      5.141      0.000       0.095       0.212
# Max_dwp_1     -0.0903      0.012     -7.531      0.000      -0.114      -0.067
# Max_dwp_3     -0.0139      0.012     -1.150      0.250      -0.038       0.010
# Min_dwp_1      0.0079      0.020      0.395      0.693      -0.031       0.047
# Min_dwp_2     -0.0272      0.021     -1.307      0.191      -0.068       0.014
# Min_dwp_3     -0.0957      0.020     -4.786      0.000      -0.135      -0.056
# ==============================================================================
# Omnibus:                      349.284   Durbin-Watson:                   1.706
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1600.282
# Skew:                          -0.363   Prob(JB):                         0.00
# Kurtosis:                       6.176   Cond. No.                         394.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = X.drop('Min_dwp_1', axis=1)

# (5) Fit the model 
model = sm.OLS(y, X).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Avg_temp   R-squared:                       0.937
# Model:                            OLS   Adj. R-squared:                  0.937
# Method:                 Least Squares   F-statistic:                     4119.
# Date:                Mon, 28 Jan 2019   Prob (F-statistic):               0.00
# Time:                        11:54:50   Log-Likelihood:                -7279.4
# No. Observations:                3619   AIC:                         1.459e+04
# Df Residuals:                    3605   BIC:                         1.467e+04
# Df Model:                          13
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.8795      0.168     11.159      0.000       1.549       2.210
# Temp_max_1     0.2963      0.013     23.704      0.000       0.272       0.321
# Temp_max_2     0.0503      0.013      3.815      0.000       0.024       0.076
# Temp_max_3     0.0469      0.013      3.601      0.000       0.021       0.072
# Temp_min_1     0.1518      0.017      9.127      0.000       0.119       0.184
# Temp_min_2     0.0420      0.018      2.317      0.021       0.006       0.078
# Temp_min_3     0.1795      0.017     10.490      0.000       0.146       0.213
# Avg_dwp_1      0.3633      0.022     16.316      0.000       0.320       0.407
# Avg_dwp_2     -0.1084      0.028     -3.939      0.000      -0.162      -0.054
# Avg_dwp_3      0.1520      0.030      5.139      0.000       0.094       0.210
# Max_dwp_1     -0.0912      0.012     -7.739      0.000      -0.114      -0.068
# Max_dwp_3     -0.0137      0.012     -1.140      0.254      -0.037       0.010
# Min_dwp_2     -0.0243      0.019     -1.248      0.212      -0.062       0.014
# Min_dwp_3     -0.0941      0.020     -4.809      0.000      -0.132      -0.056
# ==============================================================================
# Omnibus:                      349.202   Durbin-Watson:                   1.707
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1601.028
# Skew:                          -0.362   Prob(JB):                         0.00
# Kurtosis:                       6.177   Cond. No.                         386.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = X.drop('Max_dwp_3', axis=1)

# (5) Fit the model 
model = sm.OLS(y, X).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Avg_temp   R-squared:                       0.937
# Model:                            OLS   Adj. R-squared:                  0.937
# Method:                 Least Squares   F-statistic:                     4462.
# Date:                Mon, 28 Jan 2019   Prob (F-statistic):               0.00
# Time:                        11:55:22   Log-Likelihood:                -7280.1
# No. Observations:                3619   AIC:                         1.459e+04
# Df Residuals:                    3606   BIC:                         1.467e+04
# Df Model:                          12
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.8768      0.168     11.143      0.000       1.547       2.207
# Temp_max_1     0.2969      0.012     23.770      0.000       0.272       0.321
# Temp_max_2     0.0511      0.013      3.885      0.000       0.025       0.077
# Temp_max_3     0.0414      0.012      3.421      0.001       0.018       0.065
# Temp_min_1     0.1510      0.017      9.084      0.000       0.118       0.184
# Temp_min_2     0.0422      0.018      2.327      0.020       0.007       0.078
# Temp_min_3     0.1823      0.017     10.769      0.000       0.149       0.216
# Avg_dwp_1      0.3646      0.022     16.390      0.000       0.321       0.408
# Avg_dwp_2     -0.1064      0.027     -3.874      0.000      -0.160      -0.053
# Avg_dwp_3      0.1346      0.025      5.310      0.000       0.085       0.184
# Max_dwp_1     -0.0921      0.012     -7.834      0.000      -0.115      -0.069
# Min_dwp_2     -0.0252      0.019     -1.297      0.195      -0.063       0.013
# Min_dwp_3     -0.0900      0.019     -4.678      0.000      -0.128      -0.052
# ==============================================================================
# Omnibus:                      349.390   Durbin-Watson:                   1.707
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1602.585
# Skew:                          -0.362   Prob(JB):                         0.00
# Kurtosis:                       6.178   Cond. No.                         370.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
X = X.drop('Min_dwp_2', axis=1)

# (5) Fit the model 
model = sm.OLS(y, X).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Avg_temp   R-squared:                       0.937
# Model:                            OLS   Adj. R-squared:                  0.937
# Method:                 Least Squares   F-statistic:                     4867.
# Date:                Mon, 28 Jan 2019   Prob (F-statistic):               0.00
# Time:                        11:56:06   Log-Likelihood:                -7280.9
# No. Observations:                3619   AIC:                         1.459e+04
# Df Residuals:                    3607   BIC:                         1.466e+04
# Df Model:                          11
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.9006      0.167     11.351      0.000       1.572       2.229
# Temp_max_1     0.2967      0.012     23.754      0.000       0.272       0.321
# Temp_max_2     0.0552      0.013      4.318      0.000       0.030       0.080
# Temp_max_3     0.0413      0.012      3.412      0.001       0.018       0.065
# Temp_min_1     0.1511      0.017      9.095      0.000       0.119       0.184
# Temp_min_2     0.0347      0.017      2.017      0.044       0.001       0.068
# Temp_min_3     0.1852      0.017     11.030      0.000       0.152       0.218
# Avg_dwp_1      0.3613      0.022     16.347      0.000       0.318       0.405
# Avg_dwp_2     -0.1266      0.023     -5.606      0.000      -0.171      -0.082
# Avg_dwp_3      0.1436      0.024      5.887      0.000       0.096       0.191
# Max_dwp_1     -0.0910      0.012     -7.758      0.000      -0.114      -0.068
# Min_dwp_3     -0.1018      0.017     -6.015      0.000      -0.135      -0.069
# ==============================================================================
# Omnibus:                      350.079   Durbin-Watson:                   1.705
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1604.420
# Skew:                          -0.364   Prob(JB):                         0.00
# Kurtosis:                       6.180   Cond. No.                         360.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Split the data into training and testing
from sklearn.model_selection import train_test_split
X = X.drop('const', axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
# Create a StandardScater model and fit it to the training data

X_scaler = StandardScaler().fit(X_train)

# %%
from sklearn.externals import joblib
scaler_filename = "concat_scaler.save"
joblib.dump(X_scaler, scaler_filename)
# Out:
# ['concat_scaler.save']

# %%
# Transform the training and testing data using the X_scaler and y_scaler models

### BEGIN SOLUTION
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
from sklearn.linear_model import Ridge
from sklearn.metrics import r2_score, mean_squared_error

# %%
# define the model
ridge = Ridge(alpha=0.05, normalize=True)

# traub the model/ fit the model to the traingin data
ridge.fit(X_train_scaled, y_train)

# use evaluation metrics to determine model performance
y_ridge_prediction = ridge.predict(X_test_scaled)

# %%
# use evaluation metrics to determine model performance
r2_ridge = r2_score(y_test, y_ridge_prediction)
print("The R^2 score for test data is:", r2_ridge)
# Out:
# The R^2 score for test data is: 0.9319056789035403

# %%
# save model
import pickle
with open('ridge_concat_feats.pkl', 'wb') as file:
    pickle.dump(ridge, file)

# %%
from sklearn.linear_model import LinearRegression
# define the model
linear = LinearRegression()

# traub the model/ fit the model to the traingin data
linear.fit(X_train_scaled, y_train)

# predict
y_linear_prediction = linear.predict(X_test_scaled)

# %%
# use evaluation metrics to determine model performance
r2_linear = r2_score(y_test, y_linear_prediction)

print("The R^2 score for test data is:", r2_linear)
# Out:
# The R^2 score for test data is: 0.9343595898061711

# %%
#save model
import pickle
with open('linear_concat_feats.pkl', 'wb') as file:
    pickle.dump(linear, file)

# %%
from sklearn.metrics import mean_absolute_error, median_absolute_error  
print("The Explained Variance: %.2f" % linear.score(X_test_scaled, y_test))  
print("The Mean Absolute Error: %.2f degrees celsius" % mean_absolute_error(y_test, y_linear_prediction))  
print("The Median Absolute Error: %.2f degrees celsius" % median_absolute_error(y_test, y_linear_prediction))
# Out:
# The Explained Variance: 0.93
# The Mean Absolute Error: 1.25 degrees celsius
# The Median Absolute Error: 0.87 degrees celsius
